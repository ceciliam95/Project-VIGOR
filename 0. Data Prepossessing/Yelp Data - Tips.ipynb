# %%
#Import Library
import json
import pandas as pd
import nltk
import re
import numpy as np
import matplotlib as plt

# %%
tip_df = pd.read_json("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/tip.json", lines = True)
business_rester = pd.read_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/business_rester.pkl")

# %%
tip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1223094 entries, 0 to 1223093
# Data columns (total 5 columns):
# business_id         1223094 non-null object
# compliment_count    1223094 non-null int64
# date                1223094 non-null datetime64[ns]
# text                1223094 non-null object
# user_id             1223094 non-null object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 46.7+ MB

# %%
tip_df
# Out:
#                     business_id  compliment_count                date  \
# 0        VaKXUpmWTTWDKbpJ3aQdMw                 0 2014-03-27 03:51:24
# 1        OPiPeoJiv92rENwbq76orA                 0 2013-05-25 06:00:56
# 2        5KheTjYPu1HcQzQFtm4_vw                 0 2011-12-26 01:46:17
# 3        TkoyGi8J7YFjA6SbaRzrxg                 0 2014-03-23 21:32:49
# 4        AkL6Ous6A1atZejfZXn1Bg                 0 2012-10-06 00:19:27
# 5        kj1p6NwUGROOoqNySf0I1Q                 0 2011-12-31 18:02:42
# 6        0hudPyuCBlKg79OwKBw-eQ                 0 2012-10-11 23:06:21
# 7        r49iBfbnfoK7yt4rdsL_7g                 0 2016-01-05 06:39:33
# 8        YCRCFBr6myPS49on2aS2pQ                 0 2017-03-13 03:29:40
# 9        RTBIiq-fJUXRsrzbL4MCqw                 0 2013-02-08 20:55:15
# 10       qrSsS0pk7SL67MP5nN8tlg                 0 2013-12-22 05:10:12
# 11       oGASRzKGpuiP12ilQH_nKg                 0 2010-03-04 15:41:16
# ...

# %%
#business_id = pd.DataFrame(business_rester['business_id'])
rester_tip = business_id.merge(tip_df,'left')
#rester_tip = rester_checkin.loc[:,['business_id','date']]

# %%
#business_id
print(rester_tip.info())
print(tip_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819187 entries, 0 to 819186
# Data columns (total 5 columns):
# business_id         819187 non-null object
# compliment_count    810342 non-null float64
# date                810342 non-null datetime64[ns]
# text                810342 non-null object
# user_id             810342 non-null object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 37.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1223094 entries, 0 to 1223093
# Data columns (total 5 columns):
# business_id         1223094 non-null object
# compliment_count    1223094 non-null int64
# date                1223094 non-null datetime64[ns]
# text                1223094 non-null object
# user_id             1223094 non-null object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 46.7+ MB
# None

# %%
len(rester_tip['business_id'].unique())
# Out:
# 59371

# %% [markdown]
# #Data Export

# %%
rester_tip.to_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/rester_tip.pkl")
