# %%
#Import Library
import json
import pandas as pd
import nltk
import re
import numpy as np
import matplotlib as plt

# %%
#user_df = pd.read_json("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/user.json", lines = True)

rester_review = pd.read_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/review_rester.pkl")

# %%
rester_review['business-']
# Out:
#                     business_id  cool                date  funny  \
# 0        QXAEGFB4oINsVuTFxEYKFQ     0 2017-01-27 21:54:30      2
# 1        QXAEGFB4oINsVuTFxEYKFQ     0 2013-06-24 23:11:30      0
# 2        QXAEGFB4oINsVuTFxEYKFQ     0 2016-01-04 12:59:22      0
# 3        QXAEGFB4oINsVuTFxEYKFQ     0 2014-05-09 02:38:43      0
# 4        QXAEGFB4oINsVuTFxEYKFQ     2 2011-03-21 14:39:55      1
# 5        QXAEGFB4oINsVuTFxEYKFQ     0 2016-08-13 20:31:21      0
# 6        QXAEGFB4oINsVuTFxEYKFQ     0 2015-02-17 00:10:02      0
# 7        QXAEGFB4oINsVuTFxEYKFQ     0 2017-01-02 20:32:29      0
# 8        QXAEGFB4oINsVuTFxEYKFQ     1 2016-01-18 17:49:39      0
# 9        QXAEGFB4oINsVuTFxEYKFQ     0 2015-08-20 03:31:45      0
# 10       QXAEGFB4oINsVuTFxEYKFQ     2 2010-11-23 00:21:58      2
# 11       QXAEGFB4oINsVuTFxEYKFQ     0 2016-05-21 01:44:12      0
# 12       QXAEGFB4oINsVuTFxEYKFQ     1 2015-02-24 04:32:58      0
# ...

# %%
print(user_df.info())
user_df.head(20)

# %%
#Count friends:
user_df['friend_count'] = user_df['friends'].apply(lambda x: len(x.split(',')))

# %%
user_df.head(10)

# %%
# I will only extract users who commented business rest
rester_review.head(10)
# Out:
#               business_id  compliment_count                date  \
# 0  QXAEGFB4oINsVuTFxEYKFQ               0.0 2016-08-08 01:48:14
# 1  QXAEGFB4oINsVuTFxEYKFQ               0.0 2013-06-21 23:44:22
# 2  QXAEGFB4oINsVuTFxEYKFQ               0.0 2017-10-07 00:56:30
# 3  QXAEGFB4oINsVuTFxEYKFQ               1.0 2016-08-21 00:01:11
# 4  QXAEGFB4oINsVuTFxEYKFQ               0.0 2014-03-29 00:03:16
# 5  QXAEGFB4oINsVuTFxEYKFQ               0.0 2011-07-27 18:16:35
# 6  QXAEGFB4oINsVuTFxEYKFQ               0.0 2015-06-23 22:45:00
# 7  QXAEGFB4oINsVuTFxEYKFQ               0.0 2018-03-03 23:54:06
# 8  QXAEGFB4oINsVuTFxEYKFQ               0.0 2014-07-16 23:08:55
# 9  QXAEGFB4oINsVuTFxEYKFQ               0.0 2015-11-01 00:38:45
#
#                                                 text                 user_id
# 0  Spring & egg rolls are great, get them with ex...  fENhF1F6I9c2ssnkfprYzw
# 1  Vile.  Worst meal I've had in years.  Absolute...  RscJR5zqb3WL4eQezBX5rA
# ...

# %%
user_id = pd.DataFrame(rester_tip['user_id'].unique())
user_id.columns = ['user_id']
user_rester = user_id.merge(user_df, on = 'user_id', how = 'left')
user_rester.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252465 entries, 0 to 252464
# Data columns (total 23 columns):
# user_id               252464 non-null object
# average_stars         252464 non-null float64
# compliment_cool       252464 non-null float64
# compliment_cute       252464 non-null float64
# compliment_funny      252464 non-null float64
# compliment_hot        252464 non-null float64
# compliment_list       252464 non-null float64
# compliment_more       252464 non-null float64
# compliment_note       252464 non-null float64
# compliment_photos     252464 non-null float64
# compliment_plain      252464 non-null float64
# compliment_profile    252464 non-null float64
# compliment_writer     252464 non-null float64
# cool                  252464 non-null float64
# elite                 252464 non-null object
# fans                  252464 non-null float64
# friends               252464 non-null object
# funny                 252464 non-null float64
# ...

# %%
user_rester.head(20)
# Out:
#                    user_id  average_stars  compliment_cool  compliment_cute  \
# 0   fENhF1F6I9c2ssnkfprYzw           3.98              5.0              0.0
# 1   RscJR5zqb3WL4eQezBX5rA           2.86              0.0              0.0
# 2   nyl_1VcRIAyI55bb_scpdw           3.85            132.0              0.0
# 3   ci8R1Bg83hNwXPyHAEzAFA           3.76             42.0              0.0
# 4   TjsBbWAfwxWEXPxaLNv5SQ           3.42             40.0              0.0
# 5   ismHJRDRvxw8MYKng9R_yg           4.28              0.0              0.0
# 6   CjbfWpCRLbA-L_eS_ztd6Q           3.41             38.0              1.0
# 7   oIHhfloe5VQamDFDB2dr1Q           3.61             18.0              0.0
# 8   ZVLMi7_FcWu-04_EbQF4HQ           4.07              0.0              0.0
# 9   iBBLkWtXWzOUUjhT7IqUBA           3.51             11.0              0.0
# 10  Weyd9u16itD_Li91RYLPQA           3.76              0.0              0.0
# ...

# %% [markdown]
# #Data Export

# %%
user_df.to_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/user_df.pkl")
user_rester.to_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/user_rester.pkl")
