# %%
#Import Library
import json
import pandas as pd
import nltk
import re
import numpy as np
import matplotlib as plt

# %%
checkin_df = pd.read_json("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/checkin.json", lines = True)
business_clean4 = pd.read_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/Business/business_clean4.pkl")

# %%
checkin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161950 entries, 0 to 161949
# Data columns (total 2 columns):
# business_id    161950 non-null object
# date           161950 non-null object
# dtypes: object(2)
# memory usage: 2.5+ MB

# %%
checkin_df2 = checkin_df.merge(business_clean4, on = 'business_id', how = 'inner')

# %%
checkin_df
# Out:
#                    business_id  \
# 0       --1UhMGODdWsrMastO9DZw
# 1       --6MefnULPED_I942VcFNA
# 2       --7zmmkVg-IMGaXbuVd0SQ
# 3       --8LPVSo5i0Oo61X01sV9A
# 4       --9QQLMTbFzLJ_oT-ON3Xw
# 5       --9e1ONYQuAa-CB_Rrw7Tw
# 6       --DaPTJW3-tB1vP-PfdTEg
# 7       --DdmeR16TRb3LsjG0ejrQ
# 8       --EF5N7P70J_UYBTPypYlA
# 9       --EX4rRznJrltyn-34Jz1w
# 10      --FBCX-N37CMYDfs790Bnw
# 11      --FLdgM0GNpXVMn74ppCGw
# 12      --GM_ORV2cYS-h38DSaCLw
# 13      --Gc998IMjLn8yr-HTzGUg
# 14      --I7YYLada0tSLkORTHb5Q
# 15      --KCl2FvVQpvjzmZSPyviA
# 16      --KQsXc-clkO7oHRqGzSzg
# 17      --Rsj71PBe31h5YljVseKA
# 18      --S62v0QgkqQaVUhFnNHrw
# 19      --SrzpvFLwP_YFwB_Cetow
# 20      --TcDRzRIxhvHM4DSgEuMA
# 21      --U98MNlDym2cLn36BBPgQ
# 22      --WsruI0IGEoeRmkErU5Gg
# 23      --Y7NhBKzLTbNliMUX_wfg
# 24      --YPwqIlRJrhHkJcjY3eiA
# 25      --ab39IjZR_xUf81WyTyHg
# 26      --cZ6Hhc9F7VkKXxHMVZSQ
# 27      --cgVkbWTiga3OYTkymKqA
# 28      --cjBEbXMI2obtaRHNSFrA
# ...

# %%
#left join rester and checkin
#df1.merge(df2, left_on='lkey', right_on='rkey')
rester_checkin = business_rester.merge(checkin_df,'left')
rester_checkin = rester_checkin.loc[:,['business_id','date']]

# %%
rester_checkin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59371 entries, 0 to 59370
# Data columns (total 2 columns):
# business_id    59371 non-null object
# date           57402 non-null object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
new_df = pd.DataFrame(rester_checkin['date'].apply(lambda x: str(x).split(',')).tolist(), index=rester_checkin['business_id']).stack()
new_df = new_df.reset_index([0, 'business_id'])
new_df.columns = ['business_id', 'checkin_date']
rester_checkin_reshape = new_df
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-babf5fe6610c> in <module>
# ----> 1 new_df = pd.DataFrame(rester_checkin['date'].apply(lambda x: str(x).split(',')).tolist(), index=rester_checkin['business_id']).stack()
#       2 new_df = new_df.reset_index([0, 'business_id'])
#       3 new_df.columns = ['business_id', 'checkin_date']
#       4 rester_checkin_reshape = new_df
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     446
#     447                     mgr = arrays_to_mgr(arrays, columns, index, columns,
# --> 448                                         dtype=dtype)
#     449                 else:
#     450                     mgr = init_ndarray(data, index, columns, dtype=dtype,
#
# ...

# %%
rester_checkin_reshape
# Out:
#                  business_id          checkin_date
# 0     gnKjwL_1w79qoiV3IC_xQQ   2010-11-13 01:00:36
# 1     gnKjwL_1w79qoiV3IC_xQQ   2010-12-19 00:49:15
# 2     gnKjwL_1w79qoiV3IC_xQQ   2011-03-02 17:27:46
# 3     gnKjwL_1w79qoiV3IC_xQQ   2011-03-26 16:07:46
# 4     gnKjwL_1w79qoiV3IC_xQQ   2011-05-20 22:21:00
# 5     gnKjwL_1w79qoiV3IC_xQQ   2011-09-21 23:02:26
# 6     gnKjwL_1w79qoiV3IC_xQQ   2011-10-02 00:10:17
# 7     gnKjwL_1w79qoiV3IC_xQQ   2011-10-06 02:43:03
# 8     gnKjwL_1w79qoiV3IC_xQQ   2011-10-13 00:38:10
# 9     gnKjwL_1w79qoiV3IC_xQQ   2011-10-15 17:10:17
# 10    gnKjwL_1w79qoiV3IC_xQQ   2011-11-11 17:43:43
# 11    gnKjwL_1w79qoiV3IC_xQQ   2011-11-19 18:19:24
# 12    gnKjwL_1w79qoiV3IC_xQQ   2011-11-25 17:30:41
# 13    gnKjwL_1w79qoiV3IC_xQQ   2011-12-01 18:18:50
# 14    gnKjwL_1w79qoiV3IC_xQQ   2011-12-05 23:38:53
# 15    gnKjwL_1w79qoiV3IC_xQQ   2011-12-16 18:00:37
# 16    gnKjwL_1w79qoiV3IC_xQQ   2011-12-29 01:17:52
# ...

# %%
#Data Export

# %%
rester_checkin.to_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/rester_checkin.pkl")
checkin_df.to_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/checkin_df.pkl")
rester_checkin_reshape.to_pickle("C:/Users/61424/Desktop/MBusA/Module 5/Business Case Study/yelp_dataset/rester_checkin_reshape_sample.pkl")
